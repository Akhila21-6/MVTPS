# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('pulsar_data_train.csv')

# %%
df.columns= df.columns.str.strip().str.replace('\n','').str.replace('','_').str.replace('_','-')

# %%
print("Class Distribution:\n", df['target_class'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Akhila Thammenenwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Akhila Thammenenwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Akhila Thammenenwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target_class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print("Class Distribution:\n", df['target_class'].value_counts())
#
# File c:\Users\Akhila Thammenenwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\Akhila Thammenenwar\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'target_class'

# %%
print(f"Data loaded. Total rows:{len(df)}")
# Out:
# Data loaded. Total rows:9273

# %%
print("Class Distribution")
print(['target_class'].value_counts())
# Out:
# Class Distribution
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 print("Class Distribution")
# ----> 2 print(['target_class'].value_counts())
#
# AttributeError: 'list' object has no attribute 'value_counts'
